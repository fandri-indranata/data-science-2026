# %% [markdown]
# <a href="https://colab.research.google.com/github/fandri-indranata/data-science-2026/blob/main/Pertemuan1_FandriIndranata_230401010180.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Fandri Indranata
# NIM: 230401010180
# Kelas: IF401

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Mahasiswa Informatika" # String
angkatan = 2023 # Integer
ipk = 3.93 # Float
aktif = True # Boolean
print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Mahasiswa Informatika
# Angkatan: 2023
# IPK : 3.93
# Aktif : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."
hasil = perkenalan("Fandri Indranata", "Informatika", 2023)
print(hasil)
# Out:
# Hai! Saya Fandri Indranata dari Informatika, angkatan 2023.

# %% [markdown]
# Kesimpulan: Pertemuan pertama mempelajari dasar penggunaan bahasa pemrograman python seperti variable, perulangan dan fungsi selain itu juga memepelajari pengguaan google Colab dan Github
